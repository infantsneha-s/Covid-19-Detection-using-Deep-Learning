# %%
import numpy as np 
import matplotlib.pyplot as plt
import glob
import cv2

from keras.models import Model, Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
import os
import seaborn as sns
from keras.applications.densenet import DenseNet201

# %%
# Read input images and assign labels based on folder names
print(os.listdir("../input/chest-xray-covid19-pneumonia/Data/"))

SIZE = 128  #Resize images
# Out:
# ['test', 'train']

# %%
from keras.preprocessing.image import array_to_img, img_to_array, load_img
#Capture training data and labels into respective lists
train_images = []
train_labels = [] 

for directory_path in glob.glob("../input/chest-xray-covid19-pneumonia/Data/train/*"):
    print(repr(directory_path))
    label = directory_path.split("/")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        print(img_path)
#         img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
#         img = cv2.resize(img, (SIZE, SIZE))
#         img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        img = img_to_array(load_img(img_path, target_size = (SIZE,SIZE)))  
        train_images.append(img)
        train_labels.append(label)

#Convert lists to arrays        
train_images = np.array(train_images)
train_labels = np.array(train_labels)
print(train_labels)
# Out:
# '../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA'
# PNEUMONIA
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3189).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2169).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(969).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(704).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1952).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2307).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2890).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2601).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1266).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1961).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2693).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1237).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(75).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1333).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1980).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1206).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(303).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3393).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1242).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(192).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2296).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3332).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2520).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(696).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2487).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(629).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2660).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1581).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2899).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(515).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1120).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1073).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(414).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3336).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(441).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3216).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2376).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2397).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2595).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(99).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1846).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(418).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(745).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2418).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3046).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2683).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2919).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3300).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1427).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1895).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(788).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(312).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2963).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(984).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3269).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1461).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3288).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1684).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2815).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1916).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(175).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1106).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(570).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1632).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(381).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2422).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2427).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1295).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(100).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1967).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(404).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1721).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2443).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2134).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2153).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3328).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2439).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2389).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1087).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1802).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(208).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1810).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(322).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1137).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(528).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2235).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1694).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1982).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3331).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3080).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3381).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1109).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1447).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1855).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3123).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(731).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1805).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2496).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(966).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2848).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1203).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2599).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1852).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1644).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2581).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(358).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2457).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(395).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(668).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(760).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2861).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(198).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2446).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1905).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(427).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(950).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1798).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(887).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(733).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3033).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1414).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(311).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(114).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2200).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(259).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(585).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2699).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2597).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1643).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1898).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3371).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1851).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2771).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(884).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(353).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(382).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(526).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2228).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3044).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(64).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2715).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1382).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2753).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(860).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2441).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2643).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(477).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1513).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(611).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2916).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1729).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2139).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1697).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1501).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(89).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(10).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1256).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2049).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1309).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1718).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(153).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1349).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1540).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2831).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1350).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2063).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(423).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2820).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2847).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(66).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1532).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1450).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3140).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2482).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2509).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3159).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2147).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(937).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1473).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1458).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2136).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3087).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1419).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(120).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1298).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(355).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1095).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(576).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2201).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1145).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3230).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1911).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1533).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2219).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1299).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3395).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(749).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2409).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1196).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1512).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2250).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3222).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1146).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(266).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2263).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(498).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1934).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(705).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1586).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3257).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(282).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(81).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3059).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1653).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1817).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(564).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1001).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1969).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3058).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(885).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2999).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2666).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1090).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(339).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2535).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(191).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(708).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2596).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(152).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2567).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1376).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2094).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(586).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2313).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3185).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3214).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1907).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1523).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1426).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(356).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(223).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3011).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2713).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1970).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1889).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1274).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3306).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(369).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2087).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(706).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(424).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(67).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3383).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1567).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1728).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2684).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2242).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3356).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2350).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2334).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2618).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2493).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2462).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2475).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2234).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2572).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(914).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2937).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(165).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1701).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1793).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2585).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1149).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(559).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1457).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2988).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2589).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(280).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(470).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2814).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1424).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(949).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1966).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2850).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(300).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(494).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1270).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2193).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2689).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(858).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1929).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1374).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1953).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2406).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1026).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3303).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2394).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(91).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3042).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(482).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1122).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1150).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(543).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1241).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2211).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(965).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(327).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3110).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1362).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1286).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2375).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(158).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1576).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1421).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(215).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(622).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2639).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1471).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2685).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(935).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(302).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2338).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3357).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(12).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(524).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1477).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1320).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2247).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3072).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2386).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2130).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1360).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1964).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1894).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1221).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(166).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(653).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1262).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(254).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1764).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2832).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1272).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1388).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2372).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(617).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3321).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(461).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1133).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3226).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2893).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1363).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(304).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(750).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(952).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1654).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1598).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1781).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(609).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1626).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2849).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1292).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(941).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(995).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1932).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1079).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2380).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(972).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(496).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(437).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1646).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1085).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1716).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(895).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1696).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(924).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3350).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2708).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3285).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(647).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3283).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3232).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1379).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2124).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(435).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(347).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1937).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(129).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1322).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1317).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(580).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3184).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(500).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2622).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1198).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(68).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2891).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1238).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2222).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1005).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(118).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3056).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2143).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3081).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2088).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1168).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2553).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2564).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(179).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3093).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2120).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1735).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1408).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1010).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3271).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2975).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3217).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3162).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1056).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1248).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(915).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3200).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2262).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3406).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1998).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1652).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2959).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2763).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2732).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2210).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(263).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2578).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1406).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3213).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3134).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(305).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3348).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2071).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3120).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(233).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(520).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2379).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1888).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1361).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2932).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1434).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(401).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1529).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1869).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2607).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1342).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2344).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(338).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(309).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1234).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1857).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2780).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1783).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(193).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1870).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(262).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3179).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1807).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3096).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(690).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1864).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1710).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1799).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2870).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1254).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1524).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1061).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1784).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2709).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3097).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1829).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1060).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2909).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3040).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3152).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(298).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2327).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(703).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2112).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1750).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3073).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3024).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2925).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2403).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3275).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2905).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(397).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1246).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2148).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1978).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2280).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(295).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(770).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1273).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1021).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2955).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2667).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1672).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3373).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2037).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3234).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(712).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1838).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1549).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3404).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2072).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1681).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(380).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(386).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(310).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(567).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3002).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1369).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1791).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1686).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1462).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(863).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3129).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1425).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1459).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1456).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2530).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1448).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1950).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(808).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(725).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(50).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3104).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1083).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1754).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3039).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2515).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(640).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(36).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2536).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2836).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2889).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1920).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2774).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3181).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1088).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2579).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1919).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2858).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1181).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2750).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2460).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1244).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2491).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3341).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(334).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2485).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(550).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1506).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2533).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2508).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1340).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(135).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(792).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1917).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1174).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2745).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(186).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2637).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(756).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2478).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3026).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(504).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2408).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(933).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2904).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2762).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(732).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2028).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(779).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(157).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(596).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3261).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(645).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(807).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(225).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3231).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1482).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2647).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(650).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(588).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1055).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1757).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(3029).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1393).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1472).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2405).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(123).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(502).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1111).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2300).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2779).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(2523).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1755).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(837).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1444).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(333).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/PNEUMONIA/PNEUMONIA(1591).jpg
# ...
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(160).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(158).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(395).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(347).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(304).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(44).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(212).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(274).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(389).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(135).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(280).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(301).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(121).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(453).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(100).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(201).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(445).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(243).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(92).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(424).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(248).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(287).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(419).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(328).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(185).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(77).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(220).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(181).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(78).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(295).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(313).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(177).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(4).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(156).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(276).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(438).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(178).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(45).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(193).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(6).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(159).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(396).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(166).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(401).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(218).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(104).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(48).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(257).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(86).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(50).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(161).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(168).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(126).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(271).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(345).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(330).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(129).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(379).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(13).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(363).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(167).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(355).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(353).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(162).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(337).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(391).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(261).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(192).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(58).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(30).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(173).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(300).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(268).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(338).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(56).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(247).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(272).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(250).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(18).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(190).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(9).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(231).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(102).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(42).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(310).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(365).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(21).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(137).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(258).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(80).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(454).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(290).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(374).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(94).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(67).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(423).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(47).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(61).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(154).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(294).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(7).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(315).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(25).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(59).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(232).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(55).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(456).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(149).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(170).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(155).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(323).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(20).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(311).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(116).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(8).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(265).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(124).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(439).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(435).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(412).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(404).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(356).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(428).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(117).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(414).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(194).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(145).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(152).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(263).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(81).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(302).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(41).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(444).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(225).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(35).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(430).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(307).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(270).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(28).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(2).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(187).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(95).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(133).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(64).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(53).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(211).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(285).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(97).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(196).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(229).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(125).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(171).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(437).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(222).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(205).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(312).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(22).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(147).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(325).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(400).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(127).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(417).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(393).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(54).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(252).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(405).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(169).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(128).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(442).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(331).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(254).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(361).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(99).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(269).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(407).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(322).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(292).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(24).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(88).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(360).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(144).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(425).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(317).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(210).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(394).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(130).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(150).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(230).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(132).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(52).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(352).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(326).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(402).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(376).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(87).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(284).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(82).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(118).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(416).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(140).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(364).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(386).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(408).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(358).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(184).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(203).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(73).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(451).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(32).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(340).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(235).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(83).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(418).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(131).jpg
# ../input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(384).jpg
# ['PNEUMONIA' 'PNEUMONIA' 'PNEUMONIA' ... 'COVID19' 'COVID19' 'COVID19']

# %%
# Capture test/validation data and labels into respective lists

test_images = []
test_labels = [] 
for directory_path in glob.glob("../input/chest-xray-covid19-pneumonia/Data/test/*"):
    fruit_label = directory_path.split("/")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
#         img = cv2.imread(img_path, cv2.IMREAD_COLOR)
#         img = cv2.resize(img, (SIZE, SIZE))
#         img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        img = img_to_array(load_img(img_path, target_size = (SIZE,SIZE)))  
        test_images.append(img)
        test_labels.append(fruit_label)

#Convert lists to arrays                
test_images = np.array(test_images)
test_labels = np.array(test_labels)
print(test_labels)
# Out:
# ['PNEUMONIA' 'PNEUMONIA' 'PNEUMONIA' ... 'COVID19' 'COVID19' 'COVID19']

# %%
#Encode labels from text to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
print(test_labels_encoded)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)
print(train_labels_encoded)
# Out:
# [2 2 2 ... 0 0 0]
# [2 2 2 ... 0 0 0]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, vx_test, y_train, vy_test = train_test_split(train_images, train_labels_encoded, test_size=0.20)

# %%
#Split data into test and train datasets (already split but assigning to meaningful convention)
x_test, y_test = test_images, test_labels_encoded

# %%
# Normalize pixel values to between 0 and 1
x_train, x_test,vx_test = x_train / 255.0, x_test / 255.0, vx_test / 255.0

#One hot encode y values for neural network. 
from keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)
vy_test_one_hot = to_categorical(vy_test)

# %%
image_size = [128,128]

from keras.layers import Dropout,AveragePooling2D

densenet201 = DenseNet201(input_shape=image_size + [3],weights=None,include_top=False)

for layer in densenet201.layers:
 layer.trainable = True

# x = Flatten()(densenet201.output)

# #Full Connected Layers
# x = Dense(512, activation='relu')(x)
# #Add dropout to avoid Overfit
# x = Dropout(0.2)(x)
# x = Dense(256, activation='relu')(x)
# x = Dense(128, activation='relu')(x)
# #Add dropout to avoid Overfit
# x = Dropout(0.4)(x)
# x = Dense(64, activation='relu')(x)


# x=Dense(3 , activation='sigmoid')(x)

x1 = densenet201.output
x1 = AveragePooling2D(name="averagepooling2d_head")(x1)
x1 = Flatten(name="flatten_head")(x1)
x1 = Dense(64, activation="relu", name="dense_head")(x1)
x1 = Dropout(0.5, name="dropout_head")(x1)
model_out = Dense(3, activation='softmax', name="predictions_head")(x1)

model = Model( inputs=densenet201.input, outputs=model_out)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 134, 134, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 64, 64, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 64, 64, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 64, 64, 64)   0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 66, 66, 64)   0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 32, 32, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 32, 32, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 32, 32, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 32, 32, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 32, 32, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 32, 32, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 32, 32, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 32, 32, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 32, 32, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 32, 32, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 32, 32, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 32, 32, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 32, 32, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 32, 32, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 32, 32, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 32, 32, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 32, 32, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 32, 32, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 32, 32, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 32, 32, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 32, 32, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 32, 32, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 32, 32, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 32, 32, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 32, 32, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 32, 32, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 32, 32, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 32, 32, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 32, 32, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 32, 32, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 32, 32, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 32, 32, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 32, 32, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 16, 16, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 16, 16, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 16, 16, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 16, 16, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 16, 16, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 16, 16, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 16, 16, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 16, 16, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 16, 16, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 16, 16, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 16, 16, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 16, 16, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 16, 16, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 16, 16, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 16, 16, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 16, 16, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 16, 16, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 16, 16, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 16, 16, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 16, 16, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 16, 16, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 16, 16, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 16, 16, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 16, 16, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 16, 16, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 16, 16, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 16, 16, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 16, 16, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 16, 16, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 16, 16, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 16, 16, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 16, 16, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 16, 16, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 16, 16, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 16, 16, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 16, 16, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 16, 16, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 16, 16, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 16, 16, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 16, 16, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 16, 16, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 16, 16, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 16, 16, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 16, 16, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 16, 16, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 16, 16, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 16, 16, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 16, 16, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 16, 16, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 16, 16, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 16, 16, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 16, 16, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 16, 16, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 16, 16, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 16, 16, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 16, 16, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 16, 16, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 16, 16, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 16, 16, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 16, 16, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 16, 16, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 16, 16, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 16, 16, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 16, 16, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 16, 16, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 16, 16, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 16, 16, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 8, 8, 256)    0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 8, 8, 256)    1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 8, 8, 256)    0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 8, 8, 128)    32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 8, 8, 128)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 8, 8, 288)    0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 8, 8, 288)    1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 8, 8, 288)    0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 8, 8, 128)    36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 8, 8, 128)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 8, 8, 320)    0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 8, 8, 320)    1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 8, 8, 320)    0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 8, 8, 128)    40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 8, 8, 128)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 8, 8, 352)    0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 8, 8, 352)    1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 8, 8, 352)    0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 8, 8, 128)    45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 8, 8, 128)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 8, 8, 384)    0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 8, 8, 384)    1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 8, 8, 384)    0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 8, 8, 128)    49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 8, 8, 128)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 8, 8, 416)    0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 8, 8, 416)    1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 8, 8, 416)    0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 8, 8, 128)    53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 8, 8, 128)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 8, 8, 448)    0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 8, 8, 448)    1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 8, 8, 448)    0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 8, 8, 128)    57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 8, 8, 128)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 8, 8, 480)    0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 8, 8, 480)    1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 8, 8, 480)    0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 8, 8, 128)    61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 8, 8, 128)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 8, 8, 512)    0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 8, 8, 512)    2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 8, 8, 512)    0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 8, 8, 128)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 8, 8, 544)    0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 8, 8, 544)    2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 8, 8, 544)    0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 8, 8, 128)    69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 8, 8, 128)    512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 8, 8, 128)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 8, 8, 576)    0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 8, 8, 576)    2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 8, 8, 576)    0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 8, 8, 128)    73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 8, 8, 128)    512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 8, 8, 128)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 8, 8, 608)    0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 8, 8, 608)    2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 8, 8, 608)    0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 8, 8, 128)    77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 8, 8, 128)    512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 8, 8, 128)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 8, 8, 640)    0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 8, 8, 640)    2560        conv4_block12_concat[0][0]
# ...
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 4, 4, 1632)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 4, 4, 1632)   6528        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 4, 4, 1632)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 4, 4, 128)    208896      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 4, 4, 1664)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 4, 4, 1664)   6656        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 4, 4, 1664)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 4, 4, 128)    212992      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 4, 4, 1696)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 4, 4, 1696)   6784        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 4, 4, 1696)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 4, 4, 128)    217088      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 4, 4, 1728)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 4, 4, 1728)   6912        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 4, 4, 1728)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 4, 4, 128)    221184      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 4, 4, 1760)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 4, 4, 1760)   7040        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 4, 4, 1760)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 4, 4, 128)    225280      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 4, 4, 1792)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 4, 4, 1792)   7168        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 4, 4, 1792)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 4, 4, 128)    229376      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 4, 4, 1824)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 4, 4, 1824)   7296        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 4, 4, 1824)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 4, 4, 128)    233472      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 4, 4, 1856)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 4, 4, 1856)   7424        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 4, 4, 1856)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 4, 4, 128)    237568      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 4, 4, 1888)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 4, 4, 1888)   7552        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 4, 4, 1888)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 4, 4, 128)    241664      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 4, 4, 1920)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 4, 4, 1920)   7680        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 4, 4, 1920)   0           bn[0][0]
# __________________________________________________________________________________________________
# averagepooling2d_head (AverageP (None, 2, 2, 1920)   0           relu[0][0]
# __________________________________________________________________________________________________
# flatten_head (Flatten)          (None, 7680)         0           averagepooling2d_head[0][0]
# __________________________________________________________________________________________________
# dense_head (Dense)              (None, 64)           491584      flatten_head[0][0]
# __________________________________________________________________________________________________
# dropout_head (Dropout)          (None, 64)           0           dense_head[0][0]
# __________________________________________________________________________________________________
# predictions_head (Dense)        (None, 3)            195         dropout_head[0][0]
# ==================================================================================================
# Total params: 18,813,763
# Trainable params: 18,584,707
# Non-trainable params: 229,056
# __________________________________________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=['accuracy'])

# %%
# last_checkpoint_path='../input/previousresults/training1/cp-0150.ckpt'

# %%
# model.load_weights(last_checkpoint_path)

# %%
import tensorflow as tf

# %%
# # import os
# # os.mkdir("/kaggle/working/training_1")
# checkpoint_path= "../working/" + "training_1/cp.ckpt"

# %%
checkpoint_path = 'training1/cp-{epoch:04d}.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

# create checkpoint callback
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                save_weights_only=True,
                                                verbose=1,
                                                period=10)

# %%
# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,save_best_only=True, verbose=1,save_freq=5)

# %%
history = model.fit(x_train,y_train_one_hot,epochs=150,batch_size=32,validation_data=(vx_test,vy_test_one_hot),callbacks=[cp_callback])
# Out:
# Epoch 1/150
# 129/129 [==============================] - 45s 186ms/step - loss: 0.9124 - accuracy: 0.7444 - val_loss: 3.1407 - val_accuracy: 0.6550
# Epoch 2/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.3611 - accuracy: 0.8687 - val_loss: 1.9174 - val_accuracy: 0.7104
# Epoch 3/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.2996 - accuracy: 0.8849 - val_loss: 0.8027 - val_accuracy: 0.5938
# Epoch 4/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.3184 - accuracy: 0.8966 - val_loss: 0.5331 - val_accuracy: 0.7658
# Epoch 5/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.2989 - accuracy: 0.8957 - val_loss: 2.4838 - val_accuracy: 0.2993
# Epoch 6/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.2479 - accuracy: 0.9218 - val_loss: 0.3875 - val_accuracy: 0.8610
# Epoch 7/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.2353 - accuracy: 0.9251 - val_loss: 2.2278 - val_accuracy: 0.1079
# Epoch 8/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.2363 - accuracy: 0.9180 - val_loss: 1.6093 - val_accuracy: 0.4772
# Epoch 9/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.2645 - accuracy: 0.9173 - val_loss: 0.3946 - val_accuracy: 0.8562
# Epoch 10/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.2308 - accuracy: 0.9293 - val_loss: 1.4536 - val_accuracy: 0.3712
#
# Epoch 00010: saving model to training1/cp-0010.ckpt
# Epoch 11/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.2005 - accuracy: 0.9357 - val_loss: 1.1038 - val_accuracy: 0.5773
# Epoch 12/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.2179 - accuracy: 0.9296 - val_loss: 1.0219 - val_accuracy: 0.5549
# Epoch 13/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1598 - accuracy: 0.9459 - val_loss: 0.5527 - val_accuracy: 0.8435
# Epoch 14/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.1739 - accuracy: 0.9399 - val_loss: 0.6133 - val_accuracy: 0.7434
# Epoch 15/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1633 - accuracy: 0.9436 - val_loss: 0.6733 - val_accuracy: 0.6842
# Epoch 16/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.1989 - accuracy: 0.9209 - val_loss: 0.3103 - val_accuracy: 0.9009
# Epoch 17/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.1852 - accuracy: 0.9368 - val_loss: 0.3102 - val_accuracy: 0.9067
# Epoch 18/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1463 - accuracy: 0.9514 - val_loss: 0.5280 - val_accuracy: 0.8591
# Epoch 19/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.1676 - accuracy: 0.9409 - val_loss: 0.4223 - val_accuracy: 0.8950
# Epoch 20/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1494 - accuracy: 0.9473 - val_loss: 1.3539 - val_accuracy: 0.5083
#
# Epoch 00020: saving model to training1/cp-0020.ckpt
# Epoch 21/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.1678 - accuracy: 0.9395 - val_loss: 0.2258 - val_accuracy: 0.9135
# Epoch 22/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.1425 - accuracy: 0.9466 - val_loss: 0.2041 - val_accuracy: 0.9378
# Epoch 23/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.1361 - accuracy: 0.9442 - val_loss: 0.9220 - val_accuracy: 0.7026
# Epoch 24/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.1368 - accuracy: 0.9492 - val_loss: 0.7470 - val_accuracy: 0.8124
# Epoch 25/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1688 - accuracy: 0.9313 - val_loss: 3.2174 - val_accuracy: 0.1497
# Epoch 26/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.1372 - accuracy: 0.9515 - val_loss: 0.3093 - val_accuracy: 0.9174
# Epoch 27/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.1256 - accuracy: 0.9483 - val_loss: 0.3273 - val_accuracy: 0.9184
# Epoch 28/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1160 - accuracy: 0.9569 - val_loss: 0.2473 - val_accuracy: 0.9397
# Epoch 29/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.1159 - accuracy: 0.9593 - val_loss: 1.4573 - val_accuracy: 0.7123
# Epoch 30/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1290 - accuracy: 0.9556 - val_loss: 1.0095 - val_accuracy: 0.7298
#
# Epoch 00030: saving model to training1/cp-0030.ckpt
# Epoch 31/150
# 129/129 [==============================] - 19s 148ms/step - loss: 0.1119 - accuracy: 0.9574 - val_loss: 5.6444 - val_accuracy: 0.3440
# Epoch 32/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1323 - accuracy: 0.9491 - val_loss: 0.2474 - val_accuracy: 0.9329
# Epoch 33/150
# 129/129 [==============================] - 19s 149ms/step - loss: 0.1236 - accuracy: 0.9523 - val_loss: 0.4631 - val_accuracy: 0.8455
# Epoch 34/150
# 129/129 [==============================] - 19s 149ms/step - loss: 0.1341 - accuracy: 0.9568 - val_loss: 0.2278 - val_accuracy: 0.9504
# Epoch 35/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.1129 - accuracy: 0.9602 - val_loss: 0.1791 - val_accuracy: 0.9485
# Epoch 36/150
# 129/129 [==============================] - 19s 150ms/step - loss: 0.0984 - accuracy: 0.9642 - val_loss: 0.2985 - val_accuracy: 0.9213
# Epoch 37/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.1289 - accuracy: 0.9529 - val_loss: 0.2950 - val_accuracy: 0.9397
# Epoch 38/150
# 129/129 [==============================] - 19s 147ms/step - loss: 0.1453 - accuracy: 0.9521 - val_loss: 0.4741 - val_accuracy: 0.8144
# Epoch 39/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1253 - accuracy: 0.9502 - val_loss: 0.3225 - val_accuracy: 0.9271
# Epoch 40/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0906 - accuracy: 0.9651 - val_loss: 0.4797 - val_accuracy: 0.8571
#
# Epoch 00040: saving model to training1/cp-0040.ckpt
# Epoch 41/150
# 129/129 [==============================] - 19s 147ms/step - loss: 0.1176 - accuracy: 0.9551 - val_loss: 0.3328 - val_accuracy: 0.9242
# Epoch 42/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1421 - accuracy: 0.9541 - val_loss: 0.5780 - val_accuracy: 0.8503
# Epoch 43/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.1042 - accuracy: 0.9614 - val_loss: 0.4617 - val_accuracy: 0.9116
# Epoch 44/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0807 - accuracy: 0.9670 - val_loss: 0.3974 - val_accuracy: 0.9271
# Epoch 45/150
# 129/129 [==============================] - 19s 147ms/step - loss: 0.0969 - accuracy: 0.9634 - val_loss: 0.3408 - val_accuracy: 0.9155
# Epoch 46/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0809 - accuracy: 0.9694 - val_loss: 0.3513 - val_accuracy: 0.8941
# Epoch 47/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0846 - accuracy: 0.9669 - val_loss: 0.6404 - val_accuracy: 0.7755
# Epoch 48/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0872 - accuracy: 0.9604 - val_loss: 0.2948 - val_accuracy: 0.9524
# Epoch 49/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0842 - accuracy: 0.9693 - val_loss: 0.2607 - val_accuracy: 0.9553
# Epoch 50/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0866 - accuracy: 0.9642 - val_loss: 0.6925 - val_accuracy: 0.8581
#
# Epoch 00050: saving model to training1/cp-0050.ckpt
# Epoch 51/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0913 - accuracy: 0.9630 - val_loss: 1.5109 - val_accuracy: 0.4772
# Epoch 52/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.1276 - accuracy: 0.9521 - val_loss: 0.3641 - val_accuracy: 0.9349
# Epoch 53/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0974 - accuracy: 0.9704 - val_loss: 0.4591 - val_accuracy: 0.9466
# Epoch 54/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0782 - accuracy: 0.9678 - val_loss: 0.2899 - val_accuracy: 0.9485
# Epoch 55/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0813 - accuracy: 0.9680 - val_loss: 0.3203 - val_accuracy: 0.9475
# Epoch 56/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0903 - accuracy: 0.9614 - val_loss: 0.2595 - val_accuracy: 0.9281
# Epoch 57/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0828 - accuracy: 0.9678 - val_loss: 0.2150 - val_accuracy: 0.9417
# Epoch 58/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.1142 - accuracy: 0.9556 - val_loss: 1.4022 - val_accuracy: 0.4237
# Epoch 59/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0996 - accuracy: 0.9615 - val_loss: 0.2774 - val_accuracy: 0.9281
# Epoch 60/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1115 - accuracy: 0.9595 - val_loss: 0.2438 - val_accuracy: 0.9223
#
# Epoch 00060: saving model to training1/cp-0060.ckpt
# Epoch 61/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.0923 - accuracy: 0.9636 - val_loss: 0.3178 - val_accuracy: 0.9427
# Epoch 62/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0740 - accuracy: 0.9739 - val_loss: 0.2721 - val_accuracy: 0.9514
# Epoch 63/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.0757 - accuracy: 0.9687 - val_loss: 0.7200 - val_accuracy: 0.8941
# Epoch 64/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1057 - accuracy: 0.9606 - val_loss: 0.3809 - val_accuracy: 0.9456
# Epoch 65/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.0725 - accuracy: 0.9718 - val_loss: 0.3742 - val_accuracy: 0.9553
# Epoch 66/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0799 - accuracy: 0.9695 - val_loss: 0.8499 - val_accuracy: 0.8882
# Epoch 67/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0775 - accuracy: 0.9674 - val_loss: 0.4439 - val_accuracy: 0.9291
# Epoch 68/150
# 129/129 [==============================] - 19s 148ms/step - loss: 0.0709 - accuracy: 0.9679 - val_loss: 0.5624 - val_accuracy: 0.9397
# Epoch 69/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0796 - accuracy: 0.9667 - val_loss: 0.3248 - val_accuracy: 0.9563
# Epoch 70/150
# 129/129 [==============================] - 19s 150ms/step - loss: 0.0746 - accuracy: 0.9672 - val_loss: 0.4802 - val_accuracy: 0.9466
#
# Epoch 00070: saving model to training1/cp-0070.ckpt
# Epoch 71/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1154 - accuracy: 0.9594 - val_loss: 0.5566 - val_accuracy: 0.9485
# Epoch 72/150
# 129/129 [==============================] - 19s 147ms/step - loss: 0.0799 - accuracy: 0.9723 - val_loss: 0.4631 - val_accuracy: 0.9514
# Epoch 73/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0571 - accuracy: 0.9782 - val_loss: 0.3723 - val_accuracy: 0.9602
# Epoch 74/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0585 - accuracy: 0.9775 - val_loss: 0.6008 - val_accuracy: 0.9339
# Epoch 75/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0849 - accuracy: 0.9659 - val_loss: 0.7131 - val_accuracy: 0.7619
# Epoch 76/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0688 - accuracy: 0.9744 - val_loss: 1.0166 - val_accuracy: 0.9203
# Epoch 77/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0766 - accuracy: 0.9685 - val_loss: 0.7834 - val_accuracy: 0.9271
# Epoch 78/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0925 - accuracy: 0.9716 - val_loss: 0.7946 - val_accuracy: 0.9193
# Epoch 79/150
# 129/129 [==============================] - 19s 149ms/step - loss: 0.0818 - accuracy: 0.9683 - val_loss: 0.8112 - val_accuracy: 0.6706
# Epoch 80/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.1152 - accuracy: 0.9579 - val_loss: 0.3169 - val_accuracy: 0.9203
#
# Epoch 00080: saving model to training1/cp-0080.ckpt
# Epoch 81/150
# 129/129 [==============================] - 19s 147ms/step - loss: 0.0606 - accuracy: 0.9749 - val_loss: 0.3578 - val_accuracy: 0.9446
# Epoch 82/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0740 - accuracy: 0.9730 - val_loss: 0.3463 - val_accuracy: 0.9514
# Epoch 83/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.0649 - accuracy: 0.9768 - val_loss: 0.4023 - val_accuracy: 0.9427
# Epoch 84/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0782 - accuracy: 0.9712 - val_loss: 0.4066 - val_accuracy: 0.9466
# Epoch 85/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.0716 - accuracy: 0.9703 - val_loss: 0.6837 - val_accuracy: 0.9466
# Epoch 86/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0836 - accuracy: 0.9672 - val_loss: 3.4390 - val_accuracy: 0.3732
# Epoch 87/150
# 129/129 [==============================] - 19s 147ms/step - loss: 0.1062 - accuracy: 0.9607 - val_loss: 0.3918 - val_accuracy: 0.9485
# Epoch 88/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0809 - accuracy: 0.9691 - val_loss: 1.2161 - val_accuracy: 0.8124
# Epoch 89/150
# 129/129 [==============================] - 20s 152ms/step - loss: 0.0818 - accuracy: 0.9727 - val_loss: 0.6396 - val_accuracy: 0.9067
# Epoch 90/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0706 - accuracy: 0.9756 - val_loss: 0.3822 - val_accuracy: 0.9436
#
# Epoch 00090: saving model to training1/cp-0090.ckpt
# Epoch 91/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.0781 - accuracy: 0.9675 - val_loss: 0.3745 - val_accuracy: 0.9524
# Epoch 92/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.0659 - accuracy: 0.9745 - val_loss: 0.5718 - val_accuracy: 0.9456
# Epoch 93/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0692 - accuracy: 0.9724 - val_loss: 0.5942 - val_accuracy: 0.9291
# Epoch 94/150
# 129/129 [==============================] - 19s 148ms/step - loss: 0.0870 - accuracy: 0.9674 - val_loss: 0.3652 - val_accuracy: 0.9534
# Epoch 95/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0684 - accuracy: 0.9745 - val_loss: 0.4291 - val_accuracy: 0.9543
# Epoch 96/150
# 129/129 [==============================] - 19s 148ms/step - loss: 0.0596 - accuracy: 0.9821 - val_loss: 0.3864 - val_accuracy: 0.9592
# Epoch 97/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0590 - accuracy: 0.9792 - val_loss: 0.4125 - val_accuracy: 0.9572
# Epoch 98/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.0560 - accuracy: 0.9808 - val_loss: 1.6796 - val_accuracy: 0.9291
# Epoch 99/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0982 - accuracy: 0.9649 - val_loss: 0.4805 - val_accuracy: 0.9534
# Epoch 100/150
# 129/129 [==============================] - 19s 148ms/step - loss: 0.0648 - accuracy: 0.9736 - val_loss: 0.4751 - val_accuracy: 0.9563
#
# Epoch 00100: saving model to training1/cp-0100.ckpt
# Epoch 101/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0870 - accuracy: 0.9686 - val_loss: 0.4049 - val_accuracy: 0.9524
# Epoch 102/150
# 129/129 [==============================] - 19s 151ms/step - loss: 0.0630 - accuracy: 0.9749 - val_loss: 0.5905 - val_accuracy: 0.9456
# Epoch 103/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0808 - accuracy: 0.9701 - val_loss: 0.4635 - val_accuracy: 0.9407
# Epoch 104/150
# 129/129 [==============================] - 19s 149ms/step - loss: 0.0689 - accuracy: 0.9755 - val_loss: 0.6063 - val_accuracy: 0.9514
# Epoch 105/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0643 - accuracy: 0.9745 - val_loss: 0.5485 - val_accuracy: 0.9427
# Epoch 106/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0802 - accuracy: 0.9720 - val_loss: 0.8564 - val_accuracy: 0.7979
# Epoch 107/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0921 - accuracy: 0.9708 - val_loss: 0.5006 - val_accuracy: 0.9534
# Epoch 108/150
# 129/129 [==============================] - 19s 148ms/step - loss: 0.0614 - accuracy: 0.9777 - val_loss: 0.3610 - val_accuracy: 0.9553
# Epoch 109/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0686 - accuracy: 0.9762 - val_loss: 0.2973 - val_accuracy: 0.9582
# Epoch 110/150
# 129/129 [==============================] - 19s 148ms/step - loss: 0.0591 - accuracy: 0.9823 - val_loss: 1.2236 - val_accuracy: 0.7930
#
# Epoch 00110: saving model to training1/cp-0110.ckpt
# Epoch 111/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0816 - accuracy: 0.9706 - val_loss: 0.5078 - val_accuracy: 0.9417
# Epoch 112/150
# 129/129 [==============================] - 19s 147ms/step - loss: 0.0702 - accuracy: 0.9751 - val_loss: 0.5207 - val_accuracy: 0.9621
# Epoch 113/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.0581 - accuracy: 0.9777 - val_loss: 0.4491 - val_accuracy: 0.9592
# Epoch 114/150
# 129/129 [==============================] - 19s 150ms/step - loss: 0.0482 - accuracy: 0.9854 - val_loss: 0.5156 - val_accuracy: 0.9650
# Epoch 115/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0544 - accuracy: 0.9811 - val_loss: 0.5849 - val_accuracy: 0.9650
# Epoch 116/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.0650 - accuracy: 0.9784 - val_loss: 0.5719 - val_accuracy: 0.9281
# Epoch 117/150
# 129/129 [==============================] - 20s 153ms/step - loss: 0.0649 - accuracy: 0.9792 - val_loss: 0.4469 - val_accuracy: 0.9252
# Epoch 118/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.1106 - accuracy: 0.9657 - val_loss: 0.3282 - val_accuracy: 0.9427
# Epoch 119/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0667 - accuracy: 0.9763 - val_loss: 0.4378 - val_accuracy: 0.9524
# Epoch 120/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.0590 - accuracy: 0.9816 - val_loss: 0.4057 - val_accuracy: 0.9592
#
# Epoch 00120: saving model to training1/cp-0120.ckpt
# Epoch 121/150
# 129/129 [==============================] - 19s 146ms/step - loss: 0.0608 - accuracy: 0.9801 - val_loss: 0.2924 - val_accuracy: 0.9524
# Epoch 122/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0559 - accuracy: 0.9810 - val_loss: 0.7224 - val_accuracy: 0.9349
# Epoch 123/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.0692 - accuracy: 0.9771 - val_loss: 1.4554 - val_accuracy: 0.8785
# Epoch 124/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.2140 - accuracy: 0.9487 - val_loss: 1.2425 - val_accuracy: 0.8202
# Epoch 125/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0761 - accuracy: 0.9691 - val_loss: 0.5048 - val_accuracy: 0.9456
# Epoch 126/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0607 - accuracy: 0.9768 - val_loss: 0.6885 - val_accuracy: 0.9524
# Epoch 127/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0523 - accuracy: 0.9788 - val_loss: 0.3726 - val_accuracy: 0.9534
# Epoch 128/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0665 - accuracy: 0.9746 - val_loss: 0.6124 - val_accuracy: 0.9232
# Epoch 129/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.0661 - accuracy: 0.9726 - val_loss: 0.4441 - val_accuracy: 0.9621
# Epoch 130/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.0666 - accuracy: 0.9753 - val_loss: 0.4636 - val_accuracy: 0.9572
#
# Epoch 00130: saving model to training1/cp-0130.ckpt
# Epoch 131/150
# 129/129 [==============================] - 18s 143ms/step - loss: 0.0570 - accuracy: 0.9801 - val_loss: 0.5414 - val_accuracy: 0.9602
# Epoch 132/150
# 129/129 [==============================] - 19s 150ms/step - loss: 0.0612 - accuracy: 0.9760 - val_loss: 0.6448 - val_accuracy: 0.9631
# Epoch 133/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.0496 - accuracy: 0.9792 - val_loss: 0.7659 - val_accuracy: 0.9582
# Epoch 134/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0596 - accuracy: 0.9753 - val_loss: 0.7065 - val_accuracy: 0.9582
# Epoch 135/150
# 129/129 [==============================] - 19s 148ms/step - loss: 0.0535 - accuracy: 0.9830 - val_loss: 0.6372 - val_accuracy: 0.9602
# Epoch 136/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0580 - accuracy: 0.9830 - val_loss: 0.8144 - val_accuracy: 0.7920
# Epoch 137/150
# 129/129 [==============================] - 18s 142ms/step - loss: 0.1025 - accuracy: 0.9628 - val_loss: 0.8083 - val_accuracy: 0.9368
# Epoch 138/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0853 - accuracy: 0.9695 - val_loss: 0.5261 - val_accuracy: 0.9553
# Epoch 139/150
# 129/129 [==============================] - 19s 150ms/step - loss: 0.0642 - accuracy: 0.9751 - val_loss: 0.5072 - val_accuracy: 0.9582
# Epoch 140/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0592 - accuracy: 0.9793 - val_loss: 0.5862 - val_accuracy: 0.9611
#
# Epoch 00140: saving model to training1/cp-0140.ckpt
# Epoch 141/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0488 - accuracy: 0.9857 - val_loss: 0.5894 - val_accuracy: 0.9611
# Epoch 142/150
# 129/129 [==============================] - 19s 148ms/step - loss: 0.0722 - accuracy: 0.9813 - val_loss: 0.5035 - val_accuracy: 0.9592
# Epoch 143/150
# 129/129 [==============================] - 19s 147ms/step - loss: 0.0563 - accuracy: 0.9800 - val_loss: 0.5566 - val_accuracy: 0.9621
# Epoch 144/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0637 - accuracy: 0.9782 - val_loss: 0.6858 - val_accuracy: 0.9631
# Epoch 145/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0514 - accuracy: 0.9843 - val_loss: 0.6814 - val_accuracy: 0.9640
# Epoch 146/150
# 129/129 [==============================] - 20s 155ms/step - loss: 0.0715 - accuracy: 0.9758 - val_loss: 0.5388 - val_accuracy: 0.9193
# Epoch 147/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0874 - accuracy: 0.9768 - val_loss: 1.2567 - val_accuracy: 0.5578
# Epoch 148/150
# 129/129 [==============================] - 19s 144ms/step - loss: 0.0917 - accuracy: 0.9765 - val_loss: 0.3543 - val_accuracy: 0.9553
# Epoch 149/150
# 129/129 [==============================] - 19s 145ms/step - loss: 0.0660 - accuracy: 0.9744 - val_loss: 0.4664 - val_accuracy: 0.9582
# Epoch 150/150
# 129/129 [==============================] - 19s 148ms/step - loss: 0.0738 - accuracy: 0.9731 - val_loss: 0.6218 - val_accuracy: 0.9349
#
# Epoch 00150: saving model to training1/cp-0150.ckpt

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1,151)
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,151)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# #get the latest checkpoint file
# checkpoint_dir = os.path.dirname(checkpoint_path)
# latest = tf.train.latest_checkpoint(checkpoint_dir)

# %%
# model.load_weights(latest)

# %%
model.evaluate(x_test,y_test_one_hot)
# Out:
# 41/41 [==============================] - 3s 61ms/step - loss: 0.3782 - accuracy: 0.9488
# [0.3782476484775543, 0.9487577676773071]

# %%
from keras.models import *

model.save('COVID19-TL-Test.hd5')

# %%
TrainedModel = load_model('COVID19-TL-Test.hd5')

TrainedModel.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 134, 134, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 64, 64, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 64, 64, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 64, 64, 64)   0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 66, 66, 64)   0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 32, 32, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 32, 32, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 32, 32, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 32, 32, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 32, 32, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 32, 32, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 32, 32, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 32, 32, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 32, 32, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 32, 32, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 32, 32, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 32, 32, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 32, 32, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 32, 32, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 32, 32, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 32, 32, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 32, 32, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 32, 32, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 32, 32, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 32, 32, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 32, 32, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 32, 32, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 32, 32, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 32, 32, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 32, 32, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 32, 32, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 32, 32, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 32, 32, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 32, 32, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 32, 32, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 32, 32, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 32, 32, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 32, 32, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 16, 16, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 16, 16, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 16, 16, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 16, 16, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 16, 16, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 16, 16, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 16, 16, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 16, 16, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 16, 16, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 16, 16, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 16, 16, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 16, 16, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 16, 16, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 16, 16, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 16, 16, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 16, 16, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 16, 16, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 16, 16, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 16, 16, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 16, 16, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 16, 16, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 16, 16, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 16, 16, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 16, 16, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 16, 16, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 16, 16, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 16, 16, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 16, 16, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 16, 16, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 16, 16, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 16, 16, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 16, 16, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 16, 16, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 16, 16, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 16, 16, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 16, 16, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 16, 16, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 16, 16, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 16, 16, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 16, 16, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 16, 16, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 16, 16, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 16, 16, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 16, 16, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 16, 16, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 16, 16, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 16, 16, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 16, 16, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 16, 16, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 16, 16, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 16, 16, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 16, 16, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 16, 16, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 16, 16, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 16, 16, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 16, 16, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 16, 16, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 16, 16, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 16, 16, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 16, 16, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 16, 16, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 16, 16, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 16, 16, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 16, 16, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 16, 16, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 16, 16, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 16, 16, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 8, 8, 256)    0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 8, 8, 256)    1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 8, 8, 256)    0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 8, 8, 128)    32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 8, 8, 128)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 8, 8, 288)    0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 8, 8, 288)    1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 8, 8, 288)    0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 8, 8, 128)    36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 8, 8, 128)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 8, 8, 320)    0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 8, 8, 320)    1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 8, 8, 320)    0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 8, 8, 128)    40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 8, 8, 128)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 8, 8, 352)    0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 8, 8, 352)    1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 8, 8, 352)    0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 8, 8, 128)    45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 8, 8, 128)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 8, 8, 384)    0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 8, 8, 384)    1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 8, 8, 384)    0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 8, 8, 128)    49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 8, 8, 128)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 8, 8, 416)    0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 8, 8, 416)    1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 8, 8, 416)    0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 8, 8, 128)    53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 8, 8, 128)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 8, 8, 448)    0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 8, 8, 448)    1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 8, 8, 448)    0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 8, 8, 128)    57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 8, 8, 128)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 8, 8, 480)    0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 8, 8, 480)    1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 8, 8, 480)    0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 8, 8, 128)    61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 8, 8, 128)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 8, 8, 512)    0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 8, 8, 512)    2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 8, 8, 512)    0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 8, 8, 128)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 8, 8, 544)    0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 8, 8, 544)    2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 8, 8, 544)    0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 8, 8, 128)    69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 8, 8, 128)    512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 8, 8, 128)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 8, 8, 576)    0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 8, 8, 576)    2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 8, 8, 576)    0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 8, 8, 128)    73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 8, 8, 128)    512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 8, 8, 128)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 8, 8, 608)    0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 8, 8, 608)    2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 8, 8, 608)    0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 8, 8, 128)    77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 8, 8, 128)    512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 8, 8, 128)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 8, 8, 640)    0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 8, 8, 640)    2560        conv4_block12_concat[0][0]
# ...
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 4, 4, 1632)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 4, 4, 1632)   6528        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 4, 4, 1632)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 4, 4, 128)    208896      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 4, 4, 1664)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 4, 4, 1664)   6656        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 4, 4, 1664)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 4, 4, 128)    212992      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 4, 4, 1696)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 4, 4, 1696)   6784        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 4, 4, 1696)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 4, 4, 128)    217088      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 4, 4, 1728)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 4, 4, 1728)   6912        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 4, 4, 1728)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 4, 4, 128)    221184      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 4, 4, 1760)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 4, 4, 1760)   7040        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 4, 4, 1760)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 4, 4, 128)    225280      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 4, 4, 1792)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 4, 4, 1792)   7168        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 4, 4, 1792)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 4, 4, 128)    229376      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 4, 4, 1824)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 4, 4, 1824)   7296        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 4, 4, 1824)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 4, 4, 128)    233472      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 4, 4, 1856)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 4, 4, 1856)   7424        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 4, 4, 1856)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 4, 4, 128)    237568      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 4, 4, 1888)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 4, 4, 1888)   7552        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 4, 4, 1888)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 4, 4, 128)    241664      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 4, 4, 1920)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 4, 4, 1920)   7680        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 4, 4, 1920)   0           bn[0][0]
# __________________________________________________________________________________________________
# averagepooling2d_head (AverageP (None, 2, 2, 1920)   0           relu[0][0]
# __________________________________________________________________________________________________
# flatten_head (Flatten)          (None, 7680)         0           averagepooling2d_head[0][0]
# __________________________________________________________________________________________________
# dense_head (Dense)              (None, 64)           491584      flatten_head[0][0]
# __________________________________________________________________________________________________
# dropout_head (Dropout)          (None, 64)           0           dense_head[0][0]
# __________________________________________________________________________________________________
# predictions_head (Dense)        (None, 3)            195         dropout_head[0][0]
# ==================================================================================================
# Total params: 18,813,763
# Trainable params: 18,584,707
# Non-trainable params: 229,056
# __________________________________________________________________________________________________

# %%
import sklearn.metrics as metrics

y_pred = TrainedModel.predict(x_test)  # shape=(n_samples, 12)
y_pred_labels = np.argmax(y_pred, axis=1)  # only necessary if output has one-hot-encoding, shape=(n_samples)

confusion_matrix = metrics.confusion_matrix(y_true=y_test, y_pred=y_pred_labels)  # shape=(12, 12)

# %%
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test,y_pred_labels )
#print(cm)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
FP = cm.sum(axis=0) - np.diag(cm) 
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)
FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)
# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
print("Sensitivity:",TPR)
# Specificity or true negative rate
TNR = TN/(TN+FP) 
print("Specificity:",TNR)
# Precision or positive predictive value
PPV = TP/(TP+FP)
print("Precision:",PPV)
# Negative predictive value
NPV = TN/(TN+FN)
print(NPV)
# Fall out or false positive rate
FPR = FP/(FP+TN)
print(FPR)
# False negative rate
FNR = FN/(TP+FN)
print(FNR)
# False discovery rate
FDR = FP/(TP+FP)
print(FDR)
# Overall accuracy for each class
ACC = (TP+TN)/(TP+FP+FN+TN)
print(ACC)
#F1-Score
F1 = 2*(PPV*TPR)/(PPV+TPR)
print("F1-Score:",F1)
# Out:
# Sensitivity: [0.94827586 0.85488959 0.98362573]
# Specificity: [0.99744027 0.98455201 0.8891455 ]
# Precision: [0.97345133 0.94755245 0.94600675]
# [0.99489362 0.95409182 0.96491228]
# [0.00255973 0.01544799 0.1108545 ]
# [0.05172414 0.14511041 0.01637427]
# [0.02654867 0.05244755 0.05399325]
# [0.99301242 0.95263975 0.95186335]
# F1-Score: [0.96069869 0.89883914 0.96444954]

# %%
#Check results on a few select images
n=np.random.randint(0, x_test.shape[0])
img = x_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
prediction = TrainedModel.predict(input_img)
y_pred_label = np.argmax(prediction, axis=1) 
y_pred_label = le.inverse_transform([y_pred_label])  #Reverse the label encoder to original name
print("The prediction for this image is: ", y_pred_label)
print("The actual label for this image is: ", test_labels[n])
# Out:
# The prediction for this image is:  ['COVID19']
# The actual label for this image is:  COVID19
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
# image_size = [128,128]

# model = DenseNet201(input_shape=image_size + [3],weights=None,include_top=True,classes=3)

# for layer in model.layers:
#  layer.trainable = True

# model.summary()

# # x = Flatten()(densenet201.output)

# # prediction = Dense(3,activation="softmax")(x)

# # model = Model(inputs=densenet201.input,outputs=prediction)

# %%
# model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=['accuracy'])

# %%
# last_checkpoint_path='../input/80epochcp/80-epoch-IT-true/cp-0050.ckpt'

# %%
# model.load_weights(last_checkpoint_path)

# %%
# # create checkpoint callback
# cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
#                                                 save_weights_only=True,
#                                                 verbose=1,
#                                                 period=10)

# %%
# history = model.fit(x_train,y_train_one_hot,epochs=70,batch_size=32,validation_data=(vx_test,vy_test_one_hot),callbacks=[cp_callback])

# %%
# loss_train = history.history['accuracy']
# loss_val = history.history['val_accuracy']
# epochs = range(1,71)
# plt.plot(epochs, loss_train, 'g', label='Training accuracy')
# plt.plot(epochs, loss_val, 'b', label='validation accuracy')
# plt.title('Training and Validation accuracy')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()

# %%
# loss_train = history.history['loss']
# loss_val = history.history['val_loss']
# epochs = range(1,71)
# plt.plot(epochs, loss_train, 'g', label='Training loss')
# plt.plot(epochs, loss_val, 'b', label='validation loss')
# plt.title('Training and Validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
# model.evaluate(x_test,y_test_one_hot)

# %%
# model.save('COVID-TT-120.hd5')

# %%
# TrainedModel = load_model('COVID-TT-120.hd5')

# %%
# feature_extractor = TrainedModel.predict(x_train)

# features = feature_extractor.reshape(feature_extractor.shape[0] ,-1)

# X_for_RF = features

# %%
# from sklearn import svm

# SVMmodel = svm.SVC(kernel='linear')

# SVMmodel.fit(X_for_RF,y_train)

# SVMmodel.score(X_for_RF,y_train)

# %%
# x_test_feature = TrainedModel.predict(x_test)

# x_test_features = x_test_feature.reshape(x_test_feature.shape[0],-1)

# %%
# prediction_SVM = SVMmodel.predict(x_test_features)

# #Inverse le transform to get original label back. 
# prediction_SVM = le.inverse_transform(prediction_SVM)

# %%
# # Print overall accuracy
# from sklearn import metrics
# print ("Accuracy = ", metrics.accuracy_score(test_labels, prediction_SVM))

# %%
# #Confusion Matrix - verify accuracy of each class
# from sklearn.metrics import confusion_matrix

# cm = confusion_matrix(test_labels, prediction_SVM)
# #print(cm)
# sns.heatmap(cm, annot=True)

# %%
# FP = cm.sum(axis=0) - np.diag(cm) 
# FN = cm.sum(axis=1) - np.diag(cm)
# TP = np.diag(cm)
# TN = cm.sum() - (FP + FN + TP)
# FP = FP.astype(float)
# FN = FN.astype(float)
# TP = TP.astype(float)
# TN = TN.astype(float)
# # Sensitivity, hit rate, recall, or true positive rate
# TPR = TP/(TP+FN)
# print("Sensitivity:",TPR)
# # Specificity or true negative rate
# TNR = TN/(TN+FP) 
# print("Specificity:",TNR)
# # Precision or positive predictive value
# PPV = TP/(TP+FP)
# print("Precision:",PPV)
# # Negative predictive value
# NPV = TN/(TN+FN)
# print(NPV)
# # Fall out or false positive rate
# FPR = FP/(FP+TN)
# print(FPR)
# # False negative rate
# FNR = FN/(TP+FN)
# print(FNR)
# # False discovery rate
# FDR = FP/(TP+FP)
# print(FDR)
# # Overall accuracy for each class
# ACC = (TP+TN)/(TP+FP+FN+TN)
# print(ACC)

# %%
# #Check results on a few select images
# n=np.random.randint(0, x_test.shape[0])
# img = x_test[n]
# plt.imshow(img)
# input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
# input_img_feature=TrainedModel.predict(input_img)
# input_img_features=input_img_feature.reshape(input_img_feature.shape[0], -1)
# prediction_SVM = SVMmodel.predict(input_img_features)[0] 
# prediction_SVM = le.inverse_transform([prediction_SVM])  #Reverse the label encoder to original name
# print("The prediction for this image is: ", prediction_SVM)
# print("The actual label for this image is: ", test_labels[n])

# %%
# from sklearn.ensemble import RandomForestClassifier
# RF_model = RandomForestClassifier()

# # Train the model on training data
# RF_model.fit(X_for_RF, y_train) #For sklearn no one hot encoding

# print(RF_model.score(X_for_RF,y_train))

# %%
# prediction_RF = RF_model.predict(x_test_features)

# #Inverse le transform to get original label back. 
# prediction_RF = le.inverse_transform(prediction_RF)

# %%
# # Print overall accuracy
# from sklearn import metrics
# print ("Accuracy = ", metrics.accuracy_score(test_labels, prediction_RF))

# #print(RF_model.score(test_labels,prediction_RF))

# %%
# #Confusion Matrix - verify accuracy of each class
# from sklearn.metrics import confusion_matrix

# cm = confusion_matrix(test_labels, prediction_RF)
# #print(cm)
# sns.heatmap(cm, annot=True)

# %%
# #Check results on a few select images
# n=np.random.randint(0, x_test.shape[0])
# img = x_test[n]
# plt.imshow(img)
# input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
# input_img_feature=TrainedModel.predict(input_img)
# input_img_features=input_img_feature.reshape(input_img_feature.shape[0], -1)
# prediction_RF = RF_model.predict(input_img_features)[0] 
# prediction_RF = le.inverse_transform([prediction_RF])  #Reverse the label encoder to original name
# print("The prediction for this image is: ", prediction_RF)
# print("The actual label for this image is: ", test_labels[n])

# %%
# FP = cm.sum(axis=0) - np.diag(cm) 
# FN = cm.sum(axis=1) - np.diag(cm)
# TP = np.diag(cm)
# TN = cm.sum() - (FP + FN + TP)
# FP = FP.astype(float)
# FN = FN.astype(float)
# TP = TP.astype(float)
# TN = TN.astype(float)
# # Sensitivity, hit rate, recall, or true positive rate
# TPR = TP/(TP+FN)
# print("Sensitivity:",TPR)
# # Specificity or true negative rate
# TNR = TN/(TN+FP) 
# print("Specificity:",TNR)
# # Precision or positive predictive value
# PPV = TP/(TP+FP)
# print("Precision:",PPV)
# # Negative predictive value
# NPV = TN/(TN+FN)
# print(NPV)
# # Fall out or false positive rate
# FPR = FP/(FP+TN)
# print(FPR)
# # False negative rate
# FNR = FN/(TP+FN)
# print(FNR)
# # False discovery rate
# FDR = FP/(TP+FP)
# print(FDR)
# # Overall accuracy for each class
# ACC = (TP+TN)/(TP+FP+FN+TN)
# print(ACC)
